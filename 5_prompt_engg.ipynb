# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("microsoft/Phi-3-mini-4k-instruct")

model = AutoModelForCausalLM.from_pretrained(
    "microsoft/Phi-3-mini-4k-instruct",
    torch_dtype='auto',
    trust_remote_code=True,
    device_map="cpu"
)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# `flash-attention` package not found, consider installing for better performance: No module named 'flash_attn'.
# Current `flash-attention` does not support `window_size`. Either upgrade or use `attn_implementation='eager'`.
# ...
#   warnings.warn(
# ...
# Loading checkpoint shards: 100%|████████████████| 2/2 [00:00<00:00,  3.73it/s]

# %%
Users/shreyas/.cache/huggingface/hub/models--microsoft--Phi-3-mini-4k-instruct/blobs

# %%
from transformers import pipeline

pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    return_full_text=False,
    max_new_tokens=500,
    do_sample=False
)

# %%
#prompt
message =[
    {"role" : "user",
     "content": "create a funny joke about chickens"}
]

output = pipe(message)
output
# Out:
# You are not running the flash-attention implementation, expect numerical differences.
# [{'generated_text': ' Why did the chicken join the band? Because it had the drumsticks!'}]

# %%
prompt = pipe.tokenizer.apply_chat_template(message, tokenize=False)
print(prompt)
# Out:
# <|user|>
# create a funny joke about chickens<|end|>
# <|endoftext|>

# %% [markdown]
# Prompt with temperature argument

# %%
output = pipe(message, do_sample=True, temperature=1)
output
# Out:
# [{'generated_text': " Why did the chicken join Facebook? Because it wanted to be a 'cluck-ter' social media influencer!"}]

# %%
output = pipe(message, do_sample=True, top_p=1)
output
# Out:
# [{'generated_text': ' Why did the chicken join the comedy club? Because everyone likes her "cluck" jokes!'}]
